# %%
# show → code input visible by default
# hide-output → output hidden by default
# show hide-output → both (can combine on one line)

import pandas as pd
#from google.cloud import bigquery
from common_lib.sql import BigQueryConnector
from common_lib.export import export_notebook_html
import os as os

# %%
query_location = './sql/baseline_dau.sql'
parameters = {
    'start_date': '2024-01-01',
}


bqc = BigQueryConnector()

cost_info = bqc.print_cost_estimate(query=query_location, is_path=True, query_parameters=parameters)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 8
#       2 parameters = {
#       3     'start_date': '2024-01-01',
#       4 }
#       7 bqc = BigQueryConnector()
# ----> 8 cost_info = bqc.print_cost_estimate(query=query_location, is_path=True, query_parameters=parameters)
#
# File ~/Desktop/DataStuff/gitrepos/testrepo/simulator/common_lib/sql.py:210, in BigQueryConnector.print_cost_estimate(self, query, is_path, query_parameters)
#     208 def print_cost_estimate(self, query: str, is_path: bool = False, query_parameters: dict = None) -> dict:
#     209     """Run a dry-run cost check and print a BigQuery-style summary. Returns the full cost_info dict."""
# --> 210     cost_info = self.check_query_cost(query=query, is_path=is_path, query_parameters=query_parameters)
#     211     size_str = self._format_bytes(cost_info['bytes_processed'])
#     212     print(f"This query will process {size_str} when run.")
#
# File ~/Desktop/DataStuff/gitrepos/testrepo/simulator/common_lib/sql.py:249, in BigQueryConnector.check_query_cost(self, query, is_path, query_parameters, cost_limit, bytes_limit)
#     229 """
#     230 Estimates the cost and data processed for a query before execution.
#     231
#    (...)    246         - 'warnings': List of warning messages
#     247 """
#     248 # Format the query
# --> 249 query = self.reformat_query(query=query, is_path=is_path, query_parameters=query_parameters)
#     251 # Run dry run to estimate bytes
#     252 logger.debug(f'Running dry run...\n{query}')
#
# File ~/Desktop/DataStuff/gitrepos/testrepo/simulator/common_lib/sql.py:57, in BigQueryConnector.reformat_query(query, is_path, query_parameters)
#      55     with open(query) as file:
#      56         query = file.read()
# ---> 57 query = query.format(**query_parameters)
#      58 return query
#
# KeyError: 'lookback_days'

# %%
data = pd.DataFrame()
data = bqc.get(query='./sql/energy.sql', is_path=True, query_parameters=parameters)

data.to_pickle('./data/energy_data.pkl')

# %%
data
# Out:
#                  user_id          dt currency    flow_reason_category  \
# 0       95D7B397ACBAB65D  2026-01-14   energy  in_game_currency_spent
# 1        FE66DECE2EA3E01  2026-01-14   energy  in_game_currency_spent
# 2       91DD156E7D14E33B  2026-01-14   energy  in_game_currency_spent
# 3       E5DB5A80C1FCD929  2026-01-14   energy  in_game_currency_spent
# 4       DBF647F9C3E8CC13  2026-01-14   energy  in_game_currency_spent
# ...                  ...         ...      ...                     ...
# 517746  ACF3984CDAC785C2  2026-01-14   energy                  reward
# 517747  F7657BAED7E11A95  2026-01-14   energy                  reward
# 517748  CF4EFF79C153BE60  2026-01-14   energy                  reward
# 517749  AEFE8CA7198FCA38  2026-01-14   energy                  reward
# 517750  5B45F9122527D0B6  2026-01-14   energy                  reward
#
#         flow_reason  n_free_economy_inflow  n_paid_economy_inflow  \
# 0               gen                   <NA>                      0
# 1               gen                   <NA>                      0
# 2               gen                   <NA>                      0
# 3               gen                   <NA>                      0
# 4               gen                   <NA>                      0
# ...             ...                    ...                    ...
# 517746  TimedAlbums                   1200                      0
# 517747  TimedAlbums                   1200                      0
# 517748  TimedAlbums                   1250                      0
# 517749  TimedAlbums                   1300                      0
# 517750  TimedAlbums                   1350                      0
#
#         n_ads_economy_inflow  n_economy_outflow
# 0                          0               1244
# 1                          0               1200
# 2                          0               1752
# 3                          0               2490
# 4                          0               1292
# ...                      ...                ...
# 517746                     0                  0
# 517747                     0                  0
# 517748                     0                  0
# 517749                     0                  0
# 517750                     0                  0
#
# [517751 rows x 9 columns]
